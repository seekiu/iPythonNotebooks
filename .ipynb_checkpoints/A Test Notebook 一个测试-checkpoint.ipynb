# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# This is just a test to see how GitHub renders iPython notebook.
#
# iPython notebook is a wonderful tool for exploring, experimenting and visualizing data.
#
# 它支持中文，还有 markdown 格式的支持，`code`、**粗体**、*斜体*都很容易。
#
# It also supports math with LaTeX format, for example:
#
# $$\int_1^2 \frac{1}{\sin(x)+3}dx = y$$

# %%
x = np.linspace(0, np.pi, 100)
y = np.sin(2 * x)
plt.plot(x, y, 'c-')
